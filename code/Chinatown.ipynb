# %%
import numpy as np
import pandas as pd
from scipy.io import arff
import pandas as pd
import pytempo
import sys
import math

# %%
train = arff.loadarff('Chinatown_TRAIN.arff')
train = pd.DataFrame(train[0])
test = arff.loadarff('Chinatown_TEST.arff')
test = pd.DataFrame(test[0])
print(train.info())
print(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   att1    20 non-null     float64
#  1   att2    20 non-null     float64
#  2   att3    20 non-null     float64
#  3   att4    20 non-null     float64
#  4   att5    20 non-null     float64
#  5   att6    20 non-null     float64
#  6   att7    20 non-null     float64
#  7   att8    20 non-null     float64
#  8   att9    20 non-null     float64
#  9   att10   20 non-null     float64
#  10  att11   20 non-null     float64
#  11  att12   20 non-null     float64
#  12  att13   20 non-null     float64
#  13  att14   20 non-null     float64
#  14  att15   20 non-null     float64
#  15  att16   20 non-null     float64
#  16  att17   20 non-null     float64
#  17  att18   20 non-null     float64
#  18  att19   20 non-null     float64
#  19  att20   20 non-null     float64
#  20  att21   20 non-null     float64
#  21  att22   20 non-null     float64
#  22  att23   20 non-null     float64
#  23  att24   20 non-null     float64
#  24  target  20 non-null     object
# dtypes: float64(24), object(1)
# memory usage: 4.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343 entries, 0 to 342
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   att1    343 non-null    float64
#  1   att2    343 non-null    float64
#  2   att3    343 non-null    float64
#  3   att4    343 non-null    float64
#  4   att5    343 non-null    float64
#  5   att6    343 non-null    float64
#  6   att7    343 non-null    float64
#  7   att8    343 non-null    float64
#  8   att9    343 non-null    float64
#  9   att10   343 non-null    float64
#  10  att11   343 non-null    float64
#  11  att12   343 non-null    float64
#  12  att13   343 non-null    float64
#  13  att14   343 non-null    float64
#  14  att15   343 non-null    float64
#  15  att16   343 non-null    float64
#  16  att17   343 non-null    float64
#  17  att18   343 non-null    float64
#  18  att19   343 non-null    float64
#  19  att20   343 non-null    float64
#  20  att21   343 non-null    float64
#  21  att22   343 non-null    float64
#  22  att23   343 non-null    float64
#  23  att24   343 non-null    float64
#  24  target  343 non-null    object
# dtypes: float64(24), object(1)
# memory usage: 67.1+ KB
# None

# %%
np_train=train.iloc[:,:-1].to_numpy()
np_train_label=train.iloc[:,-1].to_numpy()
np_train_label=np_train_label.astype(int)
np_test=test.iloc[:,:-1].to_numpy()
np_test_label=test.iloc[:,-1].to_numpy()
np_test_label=np_test_label.astype(int)

# %%
# Euclidean
def Euclidean():
    min_ed =sys.maxsize
    min_y = sys.maxsize
    result_ed=[]
    ed=[]
    for i in range(len(np_test)):
        q = np_test[i]
        min_ed =sys.maxsize
        min_y = sys.maxsize
        for j in range(len(np_train)):
            c= np_train[j]
            v = np.linalg.norm(q - c)
            if(v<min_ed):
                min_ed = v
                min_y = np_train_label[j]
        result_ed.append(min_y)
    return result_ed

# DTW
def dtw():
    min_dtw =sys.maxsize
    min_y = sys.maxsize
    ud = pytempo.univariate.distances
    result=[]
    dtw=[]
    for i in range(len(np_test)):
        q = np_test[i]
        min_dtw =sys.maxsize
        min_y = sys.maxsize
        for j in range(len(np_train)):
            c= np_train[j]
            v = ud.dtw(q, c)
            if(v<min_dtw):
                min_dtw = v
                min_y = np_train_label[j]
        result.append(min_y)
        dtw.append(min_dtw)  
    return result
def cdtw(w):
    min_cdtw =sys.maxsize
    min_y = sys.maxsize
    result_cdtw=[]
    cdtw=[]
    L = 24
    for i in range(len(np_test)):
        q = np_test[i]
        min_cdtw =sys.maxsize
        min_y = sys.maxsize
        for j in range(len(np_train)):
            c= np_train[j]
            v = ud.cdtw(q, c, (w*round(L/100)))
            if(v<min_cdtw):
                min_cdtw = v
                min_y = np_train_label[j]
        result_cdtw.append(min_y)
        cdtw.append(min_cdtw) 
    return result_cdtw

# %%
q1=0
q2=0
q3=0
ud = pytempo.univariate.distances
r1 = Euclidean()
r2 = dtw()
r3 = cdtw(0)
for i in range(len(np_test_label)):
    if r1[i]==np_test_label[i]:
        q1=q1+1
    if r2[i]==np_test_label[i]:
        q2=q2+1
    if r3[i]==np_test_label[i]:
        q3=q3+1   
a1 = q1/len(np_test_label)
a2 = q2/len(np_test_label)
a3 = q3/len(np_test_label)
print(f'Ed: {format(1-a1, ".4f")}')
print(f'DTW(Learned w): {format(1-a3, ".4f")}')
print(f'DTW(w=100): {format(1-a2, ".4f")}')
# Out:
# Ed: 0.0554
# DTW(Learned w): 0.0554
# DTW(w=100): 0.0262
