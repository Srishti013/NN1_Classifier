# %%
import numpy as np
import pandas as pd
from scipy.io import arff
import pandas as pd
import pytempo
import sys

# %%
train = arff.loadarff('MelbournePedestrian_TRAIN.arff')
train = pd.DataFrame(train[0])
test = arff.loadarff('MelbournePedestrian_TEST.arff')
test = pd.DataFrame(test[0])
print(train.info())
print(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   att1    1193 non-null   float64
#  1   att2    1190 non-null   float64
#  2   att3    1175 non-null   float64
#  3   att4    1172 non-null   float64
#  4   att5    1169 non-null   float64
#  5   att6    1191 non-null   float64
#  6   att7    1193 non-null   float64
#  7   att8    1193 non-null   float64
#  8   att9    1193 non-null   float64
#  9   att10   1193 non-null   float64
#  10  att11   1193 non-null   float64
#  11  att12   1194 non-null   float64
#  12  att13   1194 non-null   float64
#  13  att14   1194 non-null   float64
#  14  att15   1194 non-null   float64
#  15  att16   1194 non-null   float64
#  16  att17   1191 non-null   float64
#  17  att18   1194 non-null   float64
#  18  att19   1194 non-null   float64
#  19  att20   1194 non-null   float64
#  20  att21   1194 non-null   float64
#  21  att22   1194 non-null   float64
#  22  att23   1194 non-null   float64
#  23  att24   1194 non-null   float64
#  24  target  1194 non-null   object
# dtypes: float64(24), object(1)
# memory usage: 233.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2439 entries, 0 to 2438
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   att1    2436 non-null   float64
#  1   att2    2429 non-null   float64
#  2   att3    2399 non-null   float64
#  3   att4    2389 non-null   float64
#  4   att5    2412 non-null   float64
#  5   att6    2426 non-null   float64
#  6   att7    2438 non-null   float64
#  7   att8    2439 non-null   float64
#  8   att9    2439 non-null   float64
#  9   att10   2438 non-null   float64
#  10  att11   2438 non-null   float64
#  11  att12   2438 non-null   float64
#  12  att13   2438 non-null   float64
#  13  att14   2437 non-null   float64
#  14  att15   2438 non-null   float64
#  15  att16   2438 non-null   float64
#  16  att17   2430 non-null   float64
#  17  att18   2438 non-null   float64
#  18  att19   2438 non-null   float64
#  19  att20   2438 non-null   float64
#  20  att21   2438 non-null   float64
#  21  att22   2437 non-null   float64
#  22  att23   2437 non-null   float64
#  23  att24   2437 non-null   float64
#  24  target  2439 non-null   object
# dtypes: float64(24), object(1)
# memory usage: 476.5+ KB
# None

# %%
np_train=train.iloc[:,:-1].to_numpy()
np_train_label=train.iloc[:,-1].to_numpy()
np_train_label=np_train_label.astype(int)
np_test=test.iloc[:,:-1].to_numpy()
np_test_label=test.iloc[:,-1].to_numpy()
np_test_label=np_test_label.astype(int)

# %%
# Euclidean
def Euclidean():
    min_ed =sys.maxsize
    min_y = sys.maxsize
    result_ed=[]
    ed=[]
    for i in range(len(np_test)):
        q = np_test[i]
        min_ed =sys.maxsize
        min_y = sys.maxsize
        for j in range(len(np_train)):
            c= np_train[j]
            v = np.linalg.norm(q - c)
            if(v<min_ed):
                min_ed = v
                min_y = np_train_label[j]
        result_ed.append(min_y)
    return result_ed

# DTW
def dtw():
    min_dtw =sys.maxsize
    min_y = sys.maxsize
    ud = pytempo.univariate.distances
    result=[]
    dtw=[]
    for i in range(len(np_test)):
        q = np_test[i]
        min_dtw =sys.maxsize
        min_y = sys.maxsize
        for j in range(len(np_train)):
            c= np_train[j]
            v = ud.dtw(q, c)
            if(v<min_dtw):
                min_dtw = v
                min_y = np_train_label[j]
        result.append(min_y)
        dtw.append(min_dtw)  
    return result
def cdtw(w):
    min_cdtw =sys.maxsize
    min_y = sys.maxsize
    result_cdtw=[]
    cdtw=[]
    L = 24
    for i in range(len(np_test)):
        q = np_test[i]
        min_cdtw =sys.maxsize
        min_y = sys.maxsize
        for j in range(len(np_train)):
            c= np_train[j]
            v = ud.cdtw(q, c, round(w*(L/100)))
            if(v<min_cdtw):
                min_cdtw = v
                min_y = np_train_label[j]
        result_cdtw.append(min_y)
        cdtw.append(min_cdtw) 
    return result_cdtw

# %%
q1=0
q2=0
q3=0
ud = pytempo.univariate.distances
r1 = Euclidean()
r2 = dtw()
r3 = cdtw(1)
for i in range(len(np_test_label)):
    if r1[i]==np_test_label[i]:
        q1=q1+1
    if r2[i]==np_test_label[i]:
        q2=q2+1
    if r3[i]==np_test_label[i]:
        q3=q3+1   
a1 = q1/len(np_test_label)
a2 = q2/len(np_test_label)
a3 = q3/len(np_test_label)
print(f'Ed: {format(1-a1, ".4f")}')
print(f'DTW(Learned w): {format(1-a3, ".4f")}')
print(f'DTW(w=100): {format(1-a2, ".4f")}')
# Out:
# Ed: 0.1021
# DTW(Learned w): 0.1021
# DTW(w=100): 0.1665
